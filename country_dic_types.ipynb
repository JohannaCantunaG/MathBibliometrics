# %%
import json
from src import data, countries

# %%
# inputs
path_data = r"C:\Users\johanna.cantuna01\Desktop\projects\Bibliometria\data"
study_area = "Mathematics"
fields = [
    "Algebra_and_Number_Theory", "Analysis", "Applied_Mathematics", 
    "Computational_Mathematics", "Discrete_Mathematics_and_Combinatorics", "Geometry_and_Topology",
    "Logic","Miscellaneous","Modeling_and_Simulation", "Probability", "Statistics"
]

# %%
_, df_study_area = data.load_all_fields(
    path_data=path_data, 
    fields=fields,
    include_preperiod=False
)

# %%
COUNTRYS_DIC = {
    r"\bargentina\b": "Argentina", 
    r"\bbrasil\b|\bbrazil\b": "Brazil",
    r"\bchile\b": "Chile",
    r"\bcolombia\b": "Colombia", 
    r"\becuador\b": "Ecuador", 
    r"\bmexico\b": "Mexico",
    r"\bvenezuela\b": "Venezuela",
    r"\bbolivia\b": "Bolivia", 
    r"\bparaguay\b": "Paraguay", 
    r"\bperu\b|\bperú\b": "Peru", 
    r"\buruguay\b": "Uruguay",
    r"\bguatemala\b": "Guatemala",
    r"\bhonduras\b": "Honduras", 
    r"\bel salvador\b": "El Salvador",
    r"\bnicaragua\b": "Nicaragua",
    r"\bcosta rica\b": "Costa Rica",
    r"\bpanama\b|\bpanamá\b": "Panama", 
    r"\bcuba\b": "Cuba",
    r"\bdominican republic\b|\brepública dominicana\b": "Dominican Republic",
    r"\bhaiti\b|\bhaïtí\b": "Haiti", 
    r"\bpuerto rico\b": "Puerto Rico",
    r"\bjamaica\b": "Jamaica", 
    r"\btrinidad and tobago\b": "Trinidad and Tobago",
    r"\bbelize\b": "Belize",
    r"\bunited states\b": "United States",
    r"\bspain\b|\bespaña\b": "Spain", 
    r"\bfrance\b|\bfrancia\b": "France", 
    r"\bgermany\b|\balemania\b": "Germany",
    r"\bitaly\b|\bitalia\b": "Italy", 
    r"\bgreece\b|\bgrecia\b": "Greece",     
    r"\b(united kingdom|uk|england|britain|great britain)\b": "United Kingdom",
    r"\bnetherlands\b|\bpaíses bajos\b|\bholland\b": "Netherlands",
    r"\bswitzerland\b|\bsuiza\b": "Switzerland",    
    r"\bsweden\b|\bsuecia\b": "Sweden",
    r"\bnorway\b|\bnoruega\b": "Norway",
    r"\bdenmark\b|\bdinamarca\b": "Denmark",
    r"\bfinland\b|\bfinlandia\b": "Finland", 
    r"\bireland\b|\birlanda\b": "Ireland",
    r"\bbelgium\b|\bbelgica\b": "Belgium", 
    r"\baustria\b": "Austria", 
    r"\baustralia\b": "Australia", 
    r"\blaos\b": "Laos", 
    r"\bmauritius\b": "Mauritius", 
    r"\bturkey\b": "Turkey", 
    r"\bcroatia\b": "Croatia", 
    r"\bnigeria\b": "Nigeria",
    r"\bviet nam\b": "Viet Nam", 
    r"\bpoland\b": "Poland", 
    r"\bsaudi arabia\b": "Saudi Arabia", 
    r"\bslovakia\b": "Slovakia",
    r"\bisrael\b": "Israel", 
    r"\bpalestine\b": "Palestine", 
    r"\bukraine\b": "Ukraine", 
    r"\btaiwan\b": "Taiwan", 
    r"\bdemocratic republic congo\b": "Democratic Republic Congo", 
    r"\bzimbabwe\b": "Zimbabwe",
    r"\bkenya\b": "Kenya", 
    r"\balgeria\b": "Algeria", 
    r"\bsuriname\b": "Suriname", 
    r"\bmalta\b": "Malta", 
    r"\bhungary\b": "Hungary",
    r"\bphilippines\b": "Philippines",
    r"\bfiji\b": "Fiji",  
    r"\bsouth korea\b": "South Korea",  
    r"\bjordan\b": "Jordan", 
    r"\bbahrain\b": "Bahrain",
    r"\bmozambique\b": "Mozambique", 
    r"\bportugal\b": "Portugal", 
    r"\bnew zealand\b": "New Zealand", 
    r"\bburundi\b": "Burundi",
    r"\bbulgaria\b": "Bulgaria",
    r"\bnepal\b": "Nepal",
    r"\bindonesia\b": "Indonesia",
    r"\bsyrian arab republic\b": "Syrian arab Republic",
    r"\buganda\b": "Uganda",
    r"\bbotswana\b": "Botswana",
    r"\btanzania\b": "Tanzania",
    r"\bsudan\b": "Sudan",
    r"\bgeorgia\b": "Georgia",
    r"\bfrench guiana\b": "French Guiana",
    r"\bunited arab emirates\b": "United Arab Emirates",
    r"\btunisia\b": "Tunisia",
    r"\bmoldova\b": "Moldova",
    r"\bpapua new guinea\b": "Papua New Guinea",
    r"\bhong kong\b": "Hong Kong",
    r"\buzbekistan\b": "Uzbekistan",
    r"\balbania\b": "Albania",
    r"\biraq\b": "Iraq",
    r"\bcanada\b": "Canada",
    r"\brwanda\b": "Rwanda",
    r"\bchina\b": "China",
    r"\bazerbaijan\b": "Azerbaijan",
    r"\blebanon\b": "Lebanon",
    r"\bczech republic\b": "Czech Republic",
    r"\blatvia\b": "Latvia",
    r"\blithuania\b": "Lithuania", 
    r"\bnorth macedonia\b": "North Macedonia", 
    r"\bmalaysia\b": "Malaysia", 
    r"\bserbia\b": "Serbia",
    r"\bindia\b": "India", 
    r"\biceland\b": "Iceland",
    r"\bkuwait\b": "Kuwait",
    r"\bsri lanka\b": "Sri Lanka",
    r"\bmyanmar\b": "Myanmar",
    r"\bkazakhstan\b": "Kazakhstan",
    r"\bsingapore\b": "Singapore",
    r"\bmongolia\b": "Mongolia",
    r"\bghana\b": "Ghana",
    r"\bqatar\b": "Qatar",
    r"\bangola\b": "Angola",
    r"\bmalawi\b": "Malawi",
    r"\boman\b": "Oman",
    r"\bsouth africa\b": "South Africa",
    r"\bromania\b": "Romania",
    r"\bslovenia\b": "Slovenia",
    r"\bmorocco\b": "Morocco",
    r"\bbelarus\b": "Belarus",
    r"\bbangladesh\b": "Bangladesh",
    r"\bswaziland\b": "Swaziland",
    r"\bjapan\b": "Japan",
    r"\bthailand\b": "Thailand",
    r"\bcyprus\b": "Cyprus",
    r"\bluxembourg\b": "Luxembourg",
    r"\bestonia\b": "Estonia",
    r"\bpakistan\b": "Pakistan",
    r"\bethiopia\b": "Ethiopia",
    r"\bcameroon\b": "Cameroon",
    r"\bbosnia and herzegovina\b": "Bosnia and Herzegovina", 
    r"\barmenia\b": "Armenia", 
    r"\bafghanistan\b": "Afghanistan",
    r"\bzambia\b": "Zambia",
    r"\blibya\b": "Libya",
    r"\bsenegal\b": "Senegal",
    r"\bcape verde\b": "Cape Verde",
    r"\bliechtenstein\b": "Liechtenstein",
    r"\bsan marino\b": "San Marino",
    r"\btajikistan\b": "Tajikistan",
    r"\bbenin\b": "Benin",
    r"\btogo\b": "Togo",
    r"\beritrea\b": "Eritrea",
    r"\bmali\b": "Mali",
    r"\bmaldives\b": "Maldives",
    r"\bmauritania\b": "Mauritania",
    r"\bchad\b": "Chad",
    r"\bsamoa\b": "Samoa",
    r"\bgambia\b": "Gambia",
    r"\bbahamas\b": "Bahamas",
    r"\bbrunei darussalam\b": "Brunei Darussalam",
    r"\bburkina faso\b": "Burkina Faso",
    r"\bkyrgyzstan\b": "Kyrgyzstan",
    r"\byemen\b": "Yemen",
    r"\bfaroe islands\b": "Faroe Islands",
    r"\btimor-leste\b": "Timor-Leste",
    r"\bcentral african republic\b": "Central African Republic",
    r"\bmonaco\b": "Monaco",
    r"\bturkmenistan\b": "Turkmenistan",
    r"\bguadeloupe\b": "Guadeloupe",
    r"\bliberia\b": "Liberia",
    r"\bmadagascar\b": "Madagascar",
    r"\bgabon\b": "Gabon",
    r"\bniger\b": "Niger",
    r"\bguinea\b": "Guinea",
    r"\bnamibia\b": "Namibia",
    r"\bsomalia\b": "Somalia",
    r"\bcambodia\b": "Cambodia",
    r"\bnorth korea\b": "North Korea",
    r"\bdjibouti\b": "Djibouti",
    r"\bmontenegro\b": "Montenegro",
    r"\bdominica\b": "Dominica",
    r"\bsaint kitts and nevis\b": "Saint Kitts and Nevis",
    r"\bbhutan\b": "Bhutan",
    r"\bnew caledonia\b": "New Caledonia",
    r"\bsolomon islands\b": "Solomon Islands",
    r"\bcote d'ivoire\b": "Cote d'Ivoire",    
}

# %%
# input countries to matched (it can expand)
WORLD_COUNTRIES = [
    "Argentina","Bolivia","Brazil","Chile","Colombia","Costa Rica","Cuba",
    "Dominican Republic","Ecuador","El Salvador","Guatemala","Honduras",
    "Mexico","Nicaragua","Panama","Paraguay","Peru","Uruguay","Venezuela",
    "Puerto Rico","Guyana","Suriname","French Guiana",
    "Spain","Portugal","France","Germany","Italy","Greece","United Kingdom",
    "Netherlands","Switzerland","Sweden","Norway","Denmark","Finland","Ireland",
    "Belgium","Austria","Poland","Czech Republic","Hungary","Romania","Bulgaria",
    "Russia","Ukraine","Turkey",
    "United States","Canada","China","Japan","South Korea","India",
    "New Zealand","Israel","Iran","Saudi Arabia","South Africa",
    "Croatia", "Bosnia and Herzegovina", "Cyprus", "Serbia", "North Macedonia",
    "Tanzania", "Australia", "Albania","Algeria","Angola","Azerbaijan",
    "Bahrain",'Hong Kong', 'Syrian arab Republic', 'Iraq', 'Cameroon', 
    'Malawi', 'Ethiopia', 'Mauritius', 'Democratic Republic Congo', 'Estonia', 
    'United Arab Emirates', 'Burundi', 'Kenya', 'Pakistan', 'Kazakhstan', 'Luxembourg',
    'Lesotho', 'Sri Lanka', 'Swaziland', 'Taiwan', 'Latvia', 'Philippines', 
    'Uganda', 'Belarus', 'Qatar', 'Viet Nam', 'Iceland', 'Palestine', 'Ghana', 
    'Lebanon', 'Sudan', 'Trinidad And Tobago', 'Tunisia',
    'Slovakia', 'Egypt', 'Indonesia', 'Malta', 'Moldova', 'Myanmar', 'Seychelles', 
    'Laos', 'Jordan', 'Zimbabwe', 'Mongolia', 'Malaysia', 'Uzbekistan', 'Botswana', 
    'Kuwait', 'Mozambique', 'Rwanda', 'Fiji', 'Oman', 'Slovenia', 'Morocco', 
    'Papua New Guinea', 'Nepal', 'Georgia', 'Nigeria', 'Lithuania', 'Thailand', 
    'Singapore', 'Bangladesh'
]

# %%
# First pass to find countries
missing_countries, valid_hits, noise_hits = countries.find_missing_countries(
    df=df_study_area,
    col_affil="Affiliations",
    country_analise=COUNTRYS_DIC,
    world_countries=WORLD_COUNTRIES,
)

# %%
missing_countries
# Out:
# {'Egypt', 'Guyana', 'Iran', 'Lesotho', 'Seychelles'}

# %%
COUNTRYS_DIC.update({
    r"\begypt\b": "Egypt",
    r"\bguyana\b": "Guyana",
    r"\biran\b": "Iran",
    r"\blesotho\b": "Lesotho",
    r"\bseychelles\b": "Seychelles",
})

# %%
missing_countries, valid_hits, noise_hits = countries.find_missing_countries(
    df=df_study_area,
    col_affil="Affiliations",
    country_analise=COUNTRYS_DIC,
    world_countries=WORLD_COUNTRIES,
)

# %%
missing_countries
# Out:
# set()

# %%
with open("country_patterns.json", "w", encoding="utf-8") as f:
    json.dump(COUNTRYS_DIC, f, indent=4, ensure_ascii=False)
